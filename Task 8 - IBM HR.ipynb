# %% [markdown]
# # IBM HR dataset

# %% [markdown]
# ## 1. Importing the important libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Loading the dataset

# %%
ibm = pd.read_csv("/home/noura/Documents/IBM HR.csv") #loading the dataset
ibm.head() #to show the first 5 rows
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ## 3. Exploring the dataset

# %% [markdown]
# ### 3.1 Getting some information about the columns and the rows

# %%
ibm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# #### As shown the dataset has 1470 rows and 35 columns

# %% [markdown]
# ### 3.2 Checking for the missing values

# %%
#checking for the missing values
ibm.isnull()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %%
#Getting the number of the missing values
ibm.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# #### The dataset has no missing values

# %% [markdown]
# ### 3.3 Getting the names of the columns

# %%
#showing the columns in the dataset
ibm.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ### 3.4 Exploring the categories of the categorical column

# %%
#exploring the categories of Attrition column
ibm['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
#exploring the categories of BusinessTravel column
ibm['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
#exploring the categories of Department column
ibm['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
#exploring the categories of EducationField column
ibm['EducationField'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
#exploring the categories of Gender column
ibm['Gender'].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
#exploring the categories of JobRole column
ibm['JobRole'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
#exploring the categories of MaritalStatus column
ibm['MaritalStatus'].value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
#exploring the categories of Over18 column
ibm['Over18'].value_counts()
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %%
#exploring the categories of OverTime column
ibm['OverTime'].value_counts()
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %% [markdown]
# ## 4. Getting some statical information about the dataset

# %%
ibm.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ## 5. Exploratory data analysis

# %% [markdown]
# #### Q1: Who have higher performance rating, males or females?

# %%
sns.displot(data = ibm, x = 'PerformanceRating', hue = 'Gender', kind="kde", palette='rocket')

# %% [markdown]
# #### ANS: The distribution shows that males have higher performance rating than the females

# %% [markdown]
# #### Q2: What is the relationship between department and the performance?

# %%
sns.displot(data = ibm, x = 'PerformanceRating', hue = 'Department', kind="kde", palette='rocket')

# %% [markdown]
# #### Ans: The Research & Development department has the highest performance rating

# %% [markdown]
# ####
# #### Q3: How does the distance affect the employess?

# %%
sns.displot(data = ibm, x = 'DistanceFromHome', hue = 'Attrition', kind="kde",palette='rocket')

# %% [markdown]
# #### Ans:At the smaller distances the possiblity is too small for the employee to get attrited and it is the same at the larger distances, so we can say that the distance from home has nothing to do with the attrition

# %% [markdown]
# ####
# #### Q4: How does the Environmental satisification make difference in the performance rating?

# %%
sns.regplot(x="EnvironmentSatisfaction", y="PerformanceRating", data=ibm, color ='Purple')
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='PerformanceRating'>

# %% [markdown]
# #### Ans: We can conclude from the graph that there is no relationship between the Environmental satisification and the performance rating.

# %% [markdown]
# ####
# #### Q5: How does the Environmental satisification make difference in the employees attrition?

# %%
sns.displot(data = ibm, x = 'EnvironmentSatisfaction', hue = 'Attrition', kind="kde",palette='rocket')

# %% [markdown]
# #### Ans: As shown in the graph the more the employee is satisified about the environment the less he/she gets attrited.

# %% [markdown]
# #####
# #### Q6: Does the distance from the home of the employee and the company contributes in the performance rating?

# %%
sns.regplot(x="DistanceFromHome", y="PerformanceRating", data=ibm,color='Purple')
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='PerformanceRating'>

# %% [markdown]
# #### Ans: There is no relationship between the distance from home and the performance rating

# %% [markdown]
# ####
# #### Q7: How does the monthly income affects the performance rating?

# %%
sns.regplot(x='MonthlyIncome', y="PerformanceRating", data=ibm,color='Purple')
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='PerformanceRating'>

# %% [markdown]
# #### Ans: There is no relationship between the monthly income and performance rating

# %% [markdown]
# ####
# #### Q8: What is the relationship between the monthly income and the attrition?

# %%
sns.displot(data = ibm, x = 'MonthlyIncome', hue = 'Attrition', kind="kde",palette='rocket')

# %% [markdown]
# #### Ans: The higher the monthly income the lower the attrition.

# %% [markdown]
# ####
# #### Q9: How does the monthly income differ from one department to another?

# %%
sns.displot(data = ibm, x = 'MonthlyIncome', hue = 'Department', kind="kde",palette='rocket')

# %% [markdown]
# #### Ans: The employees in the research and development department have the highest monthly income.

# %% [markdown]
# ####
# #### Q10: What is the relationship between the over time and the attrition?

# %%
ibm1=ibm.iloc[:,[1,22]]
ibm1['OverTime'].replace('No',0,inplace=True)
ibm1['OverTime'].replace('Yes',1,inplace=True)
sns.displot(data = ibm1, x = 'OverTime', hue = 'Attrition', kind="kde",palette='rocket')
# Out:
# /home/noura/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %% [markdown]
# #### Ans: Zero represents that there is no over time and One represents that there is over time. The higher the over time the higher the probability for the employee to get attrited.

# %% [markdown]
# ####
# #### Q11: How does the age contributes in the attrition?

# %%
sns.displot(data = ibm, x = 'Age', hue = 'Attrition', kind="kde",palette='rocket')

# %%
ibm2=ibm.iloc[:,:2]
ibm2['Attrition'].replace('Yes',1,inplace=True)
ibm2['Attrition'].replace('No',0,inplace=True)
sns.set(rc = {'figure.figsize':(8,4)})
cmap = sns.cubehelix_palette(as_cmap=True)
ax = sns.heatmap(ibm2.corr(),annot = True, cmap=cmap)

# %% [markdown]
# #### Ans: From the heatmap and the distribution, we can conclude that there is no relationship between the age and the attrition.

# %% [markdown]
# ####
# #### Q12: How does the work life balance contributes in the attritiom?

# %%
sns.displot(data = ibm, x = 'WorkLifeBalance',hue = 'Attrition',kind="kde", palette='rocket')

# %% [markdown]
# #### Ans: The higher the work life balance, the lower the attrition.

# %% [markdown]
# #####
# #### Q13: How does the training times last year affects the performance rating?

# %%
sns.regplot(x="TrainingTimesLastYear", y="PerformanceRating", data=ibm,color='Purple')
# Out:
# <AxesSubplot:xlabel='TrainingTimesLastYear', ylabel='PerformanceRating'>

# %%
ibm3=ibm.iloc[:,[24,29]]
sns.set(rc = {'figure.figsize':(8,4)})
cmap = sns.cubehelix_palette(as_cmap=True)
ax = sns.heatmap(ibm3.corr(),annot = True, cmap=cmap)

# %% [markdown]
# #### Ans: There is no relationship between the performance rating and training times last year.

# %% [markdown]
# #####
# #### Q14: How does the job environment affects the performance rating?

# %%
sns.regplot(x="JobSatisfaction", y="PerformanceRating", data=ibm,color='Purple')
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='PerformanceRating'>

# %%
ibm3=ibm.iloc[:,[16,24]]
sns.set(rc = {'figure.figsize':(8,4)})
cmap = sns.cubehelix_palette(as_cmap=True)
ax = sns.heatmap(ibm3.corr(),annot = True, cmap=cmap)

# %% [markdown]
# #### Ans: There is no relationship between the performance rating and job satisfaction.

# %% [markdown]
# #####
# #### Q15: How does the job satisfaction affects the attrition?

# %%
sns.displot(data = ibm, x = 'JobSatisfaction',hue = 'Attrition',kind="kde", palette='rocket')

# %%
ibm2=ibm.iloc[:,[1,16]]

# %%
ibm2['Attrition'].replace('Yes',1,inplace=True)
ibm2['Attrition'].replace('No',0,inplace=True)
sns.set(rc = {'figure.figsize':(8,4)})
cmap = sns.cubehelix_palette(as_cmap=True)
ax = sns.heatmap(ibm2.corr(),annot = True, cmap=cmap)
# Out:
# /home/noura/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %% [markdown]
# #### Ans: There is no relationship between job satisfaction and attrition.

# %% [markdown]
# ####
# #### Q16: What is the relation between years in current role and attrition?

# %%
sns.displot(data = ibm, x = 'YearsInCurrentRole',hue = 'Attrition',kind="kde", palette='rocket')

# %% [markdown]
# #### Ans: When the employee stays more years in his/her role, the probabilty of the attrition decreases.

# %% [markdown]
# ##
# ### 6. NOTES

# %% [markdown]
# - Males have higher performance than females.
# - The employees that have higher environment satisfaction have less attrition rate.
# - There is no relationship between the distance from the employee's home to the company and the attrition rate.
# - There is no raletionship between the performance rating and the attrition rating.
# - The dataset shows that the employees that have less monthly income are likely to have higher attrition rate.
# - The employees in the Research & Development department have higher performance, higher monthly income, so they have less attrition rate compared to the others departments.
# - The attrition rate increases for the employees that have over time.
# - There is no relationship between the age and the attrition rate.
# - The employees noticed to have work life balance have less attrition rate.
